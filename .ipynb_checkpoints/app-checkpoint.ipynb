# %%
# Install NLTK for preprocessing
import nltk
# nltk.download('stopwords')
# nltk.download('punkt')
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import string

# Import Libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import PassiveAggressiveClassifier
from sklearn.metrics import (
    accuracy_score, classification_report, confusion_matrix,
    precision_score, recall_score, f1_score
)

# Load Data
true_df = pd.read_csv("Datasets/True.csv", dtype={'text': str}, low_memory=False)
fake_df = pd.read_csv("Datasets/Fake.csv", dtype={'text': str}, low_memory=False)

true_df['label'] = 1
fake_df['label'] = 0

data = pd.concat([true_df, fake_df])
data = data.sample(n=5000, random_state=42)

# Preprocess Text Function
stop_words = set(stopwords.words('english'))

def clean_text(text):
    if not isinstance(text, str):
        return ""
    tokens = word_tokenize(text.lower())
    tokens = [word for word in tokens if word.isalpha()]
    tokens = [word for word in tokens if word not in stop_words]
    return " ".join(tokens)

data['text'] = data['text'].apply(clean_text)

# Split Dataset
X = data['text']
y = data['label']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42, stratify=y)

# TF-IDF Vectorizer
tfidf = TfidfVectorizer(max_df=0.9, min_df=5, ngram_range=(1, 2))
X_train_vec = tfidf.fit_transform(X_train)
X_test_vec = tfidf.transform(X_test)

# Model Definitions
models = {
    'Naive Bayes': MultinomialNB(alpha=0.1),
    'Random Forest': RandomForestClassifier(n_estimators=200, max_depth=100, class_weight='balanced'),
    'Passive Aggressive': PassiveAggressiveClassifier(max_iter=1000, class_weight='balanced')
}

# Train and Evaluate
results = {}
metrics_list = []

for name, model in models.items():
    print(f"\nTraining: {name}")
    model.fit(X_train_vec, y_train)
    results[name] = model
    y_pred = model.predict(X_test_vec)

    acc = accuracy_score(y_test, y_pred) * 100
    precision = precision_score(y_test, y_pred) * 100
    recall = recall_score(y_test, y_pred) * 100
    f1 = f1_score(y_test, y_pred) * 100

    print(f"Accuracy: {acc:.2f}%")
    
    # Collect metrics
    metrics_list.append({
        'Model': name,
        'Accuracy': acc,
        'Precision': precision,
        'Recall': recall,
        'F1-Score': f1
    })

# Convert metrics to DataFrame
metrics_df = pd.DataFrame(metrics_list)
metrics_melted = metrics_df.melt(id_vars='Model', var_name='Metric', value_name='Score')

# Plot comparison
plt.figure(figsize=(10, 6))
sns.barplot(x='Model', y='Score', hue='Metric', data=metrics_melted, palette='Set2')
plt.title("Model Performance Comparison")
plt.ylabel("Score (%)")
plt.ylim(0, 100)
plt.legend(title='Metric')
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.show()

# Prediction Function
def predict_with_all_models(text):
    cleaned = clean_text(text)
    vec = tfidf.transform([cleaned])
    print("\nPredictions:")
    for name, model in results.items():
        pred = model.predict(vec)[0]
        print(f"{name}: {'Real' if pred == 1 else 'Fake'}")

# Test Inputs
test_samples = [
    "The government passed a new education reform bill to improve rural schooling.",
    "NASA launches new satellite to monitor climate change patterns.",
    "Economic experts predict a steady growth rate over the next fiscal year.",
    "Drinking diesel twice a week increases brain power, scientists say.",
    "Aliens build secret base under the White House, leak reveals.",
    "Time traveler arrested after revealing stock market secrets."
]

for sample in test_samples:
    print("\n=============================")
    print(f"Input: {sample}")
    predict_with_all_models(sample)
# Out:
# Training: Naive Bayes
# Accuracy: 91.44%
#
# Training: Random Forest
# Accuracy: 94.64%
#
# Training: Passive Aggressive
# Accuracy: 94.96%
# ...
# Input: The government passed a new education reform bill to improve rural schooling.
#
# Predictions:
# Naive Bayes: Real
# Random Forest: Fake
# Passive Aggressive: Real
#
# ...
# Input: NASA launches new satellite to monitor climate change patterns.
#
# Predictions:
# Naive Bayes: Real
# Random Forest: Fake
# Passive Aggressive: Fake
#
# ...
# Input: Economic experts predict a steady growth rate over the next fiscal year.
#
# Predictions:
# Naive Bayes: Real
# Random Forest: Fake
# Passive Aggressive: Fake
#
# ...
# Input: Drinking diesel twice a week increases brain power, scientists say.
#
# Predictions:
# Naive Bayes: Fake
# Random Forest: Fake
# Passive Aggressive: Fake
#
# ...
# Input: Aliens build secret base under the White House, leak reveals.
#
# Predictions:
# Naive Bayes: Fake
# Random Forest: Fake
# Passive Aggressive: Fake
#
# ...

# %%
from wordcloud import WordCloud

def show_wordcloud(data, label):
    text = " ".join(data[data['label'] == label]['text'])
    wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)
    plt.figure(figsize=(10, 5))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis('off')
    plt.title("Real News" if label == 1 else "Fake News")
    plt.show()

show_wordcloud(data, 0)  # Fake
show_wordcloud(data, 1)  # Real
